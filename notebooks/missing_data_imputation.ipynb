# %%
import sys
sys.path.append("../src")

from data import get_data
import numpy as np
import matplotlib.pyplot as plt
import torch
from torchvision import transforms
from torch.utils.data import DataLoader, TensorDataset, random_split

# %%
train_dataloader, val_dataloader = get_data("svhn", 32, True)
# Out:
# Using downloaded and verified file: ../data/train_32x32.mat

# %%
data = val_dataloader.dataset.dataset.data

# %%
plt.figure(figsize=(15,15))
for i in range(16):
    plt.subplot(4,4,i+1)
    im = np.moveaxis(val_dataloader.dataset.dataset.data[i,:,:], 0, 2)
    plt.imshow(im)
plt.show()
